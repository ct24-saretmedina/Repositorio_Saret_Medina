# %% [markdown]
# <a href="https://colab.research.google.com/github/ct24-saretmedina/Repositorio_Saret_Medina/blob/main/Pr%C3%A1ctica_en_Colab_Configuraci%C3%B3n_del_Entorno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola")
print("Hello")
print("Bye")
print("Colab es como un cuaderno donde puedo probar código fácilmente.")
# Out:
# Hola
# Hello
# Bye
# Colab es como un cuaderno donde puedo probar código fácilmente.

# %%
# Operaciones básicas
suma = 10 + 5
resta = 20 - 7
multiplicacion = 4 * 6
division = 25 / 5

print("Resultados:")
print("10 + 5 =", suma)
print("20 - 7 =", resta)
print("4 * 6 =", multiplicacion)
print("25 / 5 =", division)
# Out:
# Resultados:
# 10 + 5 = 15
# 20 - 7 = 13
# 4 * 6 = 24
# 25 / 5 = 5.0

# %%
nombre = "Zaza"
edad = 16
año_actual = 2025
año_nacimiento = año_actual - edad

print("Hola, soy", nombre)
print("Tengo", edad, "años")
print("Nací en el año", año_nacimiento)
# Out:
# Hola, soy Zaza
# Tengo 16 años
# Nací en el año 2009

# %% [markdown]
# ## ¿Qué aprendí?
#
# En esta práctica aprendí a:
# - Crear nuevas celdas de código en Google Colab
# - Usar el comando `print()` para mostrar mensajes
# - Trabajar con variables en Python
# - Hacer operaciones matemáticas básicas
# - Ejecutar cada celda por separado y ver los resultados
