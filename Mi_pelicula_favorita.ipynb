# %%
pelicula = {
    "título": "La razón de estar contigo",
    "director": "Lasse Hallström",
    "año": 2017,
    "género": "Drama / Familiar",
    "calificación": 9,
    "actores": ["Dennis Quaid", "Josh Gad", "Britt Robertson"]
}

print("=== Mi película favorita ===")
for clave, valor in pelicula.items():
    print(f"{clave}: {valor}")
