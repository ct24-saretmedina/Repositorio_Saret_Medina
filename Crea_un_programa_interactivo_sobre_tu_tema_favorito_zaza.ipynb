# %% [markdown]
# <a href="https://colab.research.google.com/github/ct24-saretmedina/Repositorio_Saret_Medina/blob/main/Crea_un_programa_interactivo_sobre_tu_tema_favorito_zaza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("=== DESCUBRIDOR DE TUS GUSTOS MUSICALES  ===")

nombre = input("Cómo te llamas? ")
artista = input("Quién es tu artista o banda favorita? ")
cancion = input("Cuál es tu canción favorita de ese artista? ")

calificacion = 0.0
while True:
    try:
        calificacion = float(input("Del 1 al 10, ¿cuánto te gusta la música en general? "))
        if 1 <= calificacion <= 10:
            break
        else:
            print("Por favor  ingresa un número entre 1 y 10.")
    except ValueError:
        print(" Por favor ingresa un número.")

años_escuchando = 0
while True:
    try:
        años_escuchando = int(input("¿Hace cuántos años escuchas música? "))
        if años_escuchando >= 0:
            break
        else:
            print("Por favor,ingresa un número positivo para los años.")
    except ValueError:
        print("Por favor ingresa un número entero.")

pregunta_extra = input("Cual es tu dinosaurio Favorito?")
otra_pregunta_extra = input("tienes algun superheroe,villano o antiheroe favorito?")

print("\n===  RESULTADOS  ===")
print(f"Hola {nombre}, ¡qué gusto conocerte!")
print(f"Veo que te encanta {artista}, especialmente la canción '{cancion}'.")
print(f"Le das una calificación de {calificacion}/10 a la música, ¡eso es pasión musical!")
print(f"Llevas {años_escuchando} años disfrutando de tu música favorita.")
print("te encanta la musica!")
print(f"OOH!ya veo que te gusta el {pregunta_extra} mi favorito es el carnotauro ")
print(f"gracias por el dato ya se que tu favorito es {otra_pregunta_extra}")
# Out:
# === DESCUBRIDOR DE TUS GUSTOS MUSICALES  ===
